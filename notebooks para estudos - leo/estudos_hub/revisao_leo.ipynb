# %% [markdown]
# Boas praticas de decoracao : Deixar a tela meio a meio com a biblioteca e a documentacao

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io
import seaborn as sns

import requests #biblioteca para importar csv

# %% [markdown]
# * Importanto um csv

# %%
url = 'https://raw.githubusercontent.com/BrunaFortunato-eng/aprendizagem-estatistica-agrupamento/master/exercicio/adult.csv.txt'
s = requests.get(url).content #faz o request para a url

# lendo o BD

data_raw = pd.read_csv(io.StringIO(s.decode('utf-8')))

#copia do BD para nao mexer nela
data = data_raw.copy(deep=True)

# %%
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
colunas = np.array(data.columns) #----ver colunas
print(colunas)
print('*' *50)
for n in range(0, len(colunas)):
    print(colunas[n])
    
    #--------------------------- Como que eu sei o que tem dentro de cada coluna?
print('*' *50)
data.describe()

    ##--------------------------- Como que eu sei qual eh o tipo de dados dentro de cada coluna?
print('*' *50)
data.info()
    #--------------------------- Como que eu sei a quantidade de valores nulos?
data.isnull().sum()
# Out:
# ['age' 'workclass' 'fnlwgt' 'education' 'educational-num' 'marital-status'
#  'occupation' 'relationship' 'race' 'gender' 'capital-gain' 'capital-loss'
#  'hours-per-week' 'native-country' 'income']
# **************************************************
# age
# workclass
# fnlwgt
# education
# educational-num
# marital-status
# occupation
# relationship
# race
# gender
# capital-gain
# capital-loss
# hours-per-week
# native-country
# income
# **************************************************
# **************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
# age                48842 non-null int64
# workclass          48842 non-null object
# fnlwgt             48842 non-null int64
# education          48842 non-null object
# educational-num    48842 non-null int64
# marital-status     48842 non-null object
# occupation         48842 non-null object
# ...

# %%
#verificando coluna por coluna ()
for i in colunas:
    a = data[i].value_counts()
    print(a)
# Out:
# 36    1348
# 35    1337
# 33    1335
# 23    1329
# 31    1325
#       ...
# 88       6
# 85       5
# 87       3
# 89       2
# 86       1
# Name: age, Length: 74, dtype: int64
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: workclass, dtype: int64
# 203488    21
# 190290    19
# 120277    19
# 125892    18
# 126569    18
#           ..
# 131379     1
# 160061     1
# 334224     1
# 45381      1
# 208174     1
# Name: fnlwgt, Length: 28523, dtype: int64
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# ...

# %%
data.info()
colunas_text = ['education', 'marital-status','occupation','relationship','race','gender', 'native-country', 'income' ]
colunas_num = ['age', 'fnlwgt','educational-num', 'capital-gain', 'capital-loss','hours-per-week']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
# age                48842 non-null int64
# workclass          48842 non-null object
# fnlwgt             48842 non-null int64
# education          48842 non-null object
# educational-num    48842 non-null int64
# marital-status     48842 non-null object
# occupation         48842 non-null object
# relationship       48842 non-null object
# race               48842 non-null object
# gender             48842 non-null object
# capital-gain       48842 non-null int64
# capital-loss       48842 non-null int64
# hours-per-week     48842 non-null int64
# native-country     48842 non-null object
# income             48842 non-null object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
#-------------- Correlacao entre as colunas -----------

dcorr = data[colunas_num].corr()

# %%
f = sns.heatmap(dcorr, annot = True, linewidths = 0.5)
f

# %%
f = plt.figure()

data['age'].hist()

# %%
f, (ax1, ax2, ax3) = plt.subplots(1,3) #cria a figura com subplots, 1 linha de 2 colunas

sns.distplot(data.age, color='b', ax=ax1)
sns.distplot(data.age, color='purple', ax=ax2)

# %% [markdown]
# ### Pre processamento
#
# * Binarizacao

# %%
#data.gender.value_counts()

data.gender = data.gender.map(lambda x: 1 if x == 'Male' else 0)

data.gender.value_counts()
# Out:
# 1    32650
# 0    16192
# Name: gender, dtype: int64

# %%
data.gender = data.gender.map({"Male": 1, "Female": 0})

# %%
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black       1
# ...

# %%
data['income_1'] = data.income.map({'>50K':2,'<=50K':3})

# %%
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black       1
# ...

# %% [markdown]
# ### Utilizando a biblioteca

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

#chamando o metodo
OHE = OneHotEncoder()
LE = LabelEncoder()

data['income_2'] = LE.fit_transform(data.income)

for i in colunas_text:
    data[i] = LE.fit_transform(data[i])

# %%
data.income_2
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 48837    0
# 48838    1
# 48839    0
# 48840    0
# 48841    1
# Name: income_2, Length: 48842, dtype: int64

# %% [markdown]
# ### Machine Learning
#
# * Regressao Linear = aproxima um conjunto de dados para uma reta (funcao linear)

# %%
from sklearn.linear_model import LinearRegression as lr
from sklearn.datasets import load_iris

lr
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
data_adv = pd.read_csv('Advertising.csv')

data_copy = data_adv.copy(deep=True)

#copia do BD para nao mexer nelaAa
data_copy.drop('Unnamed: 0', axis =1, inplace = True)

data_copy.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %% [markdown]
# * Separando o dataset

# %%
from sklearn.model_selection import train_test_split;


X_train, X_test, y_train, y_test = train_test_split(data_copy.TV, data_copy.sales, test_size = 0.3)

# %%
plt.scatter(X_train, y_train)

# %%
lr_1 = LinearRegression()

lr_1.fit(X_train[:,np.newaxis], y_train)



y_pred = lr_1.predict(X_test[:,np.newaxis])

y_pred


print('score:', lr_1.score(y_test[:,np.newaxis], y_pred))
# Out:
# score: -2.3079652113585065

# %%
lr_1.coef_ #coeficiente da reta
# Out:
# array([0.04850707])

# %%
lr_1.predict([[1], [0]])
# Out:
# array([7.07229267, 7.02477093])
